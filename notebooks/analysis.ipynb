# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("..//data//processed//ethiopia_economics.csv")
df.head()
# Out:
#    Year  GDP_Growth  Inflation  Unemployment
# 0  1991   -7.137480  35.722598         3.264
# 1  1992   -8.672480  10.527444         3.379
# 2  1993   13.142834   3.543066         3.235
# 3  1994    3.189965   7.593876         3.100
# 4  1995    6.127511  10.022173         3.029

# %%
df.describe()
# Out:
#               Year  GDP_Growth  Inflation  Unemployment
# count    34.000000   34.000000  34.000000     34.000000
# mean   2007.500000    6.880361  12.965603      2.939147
# std       9.958246    5.495808  12.309056      0.518873
# min    1991.000000   -8.672480  -8.484249      2.251000
# 25%    1999.250000    5.401703   6.693605      2.380000
# 50%    2007.500000    8.332696   9.996072      3.012000
# 75%    2015.750000   10.736959  19.577360      3.350250
# max    2024.000000   13.572603  44.356686      3.994000

# %%
df.set_index("Year").plot(figsize=(10,6))
plt.title("Ethiopia – Key Economic Indicators")
plt.ylabel("Percent")
plt.show()
